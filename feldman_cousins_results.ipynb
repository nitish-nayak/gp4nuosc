# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from helper import load_contour_thres, load_fitted_contour, plot_contour_image, plot_conf_contour

# %%
from matplotlib import rcParams
rcParams['font.family'] = 'serif'

# %%
dir_path = '/Users/linggeli/monte_carlo/data/'

# %%
contour_thres_68 = load_contour_thres(dir_path + 'penalty_normal/contour_normal', 68)
contour_thres_90 = load_contour_thres(dir_path + 'penalty_normal/contour_normal', 90)

# %%
np.save(dir_path + 'penalty_normal_contour_thres_68', contour_thres_68)
np.save(dir_path + 'penalty_normal_contour_thres_90', contour_thres_90)

# %%
plot_contour_image(contour_thres_90, 'NH Penalty Threshold', 4)

# %%
contour_fit = load_fitted_contour(dir_path + 'penalty_normal/contour_normal_fit.txt')

# %%
plot_contour_image(contour_fit, 'NH Fit', 4)

# %%
conf_68 = contour_fit < contour_thres_68
conf_90 = contour_fit < contour_thres_90
plot_conf_contour([conf_68, conf_90], 'NH Penalty Confidence Contours', colour='blue')

# %%
contour_thres_68 = load_contour_thres(dir_path + 'penalty_inverted/contour_inverted', 68)
contour_thres_90 = load_contour_thres(dir_path + 'penalty_inverted/contour_inverted', 90)
contour_fit = load_fitted_contour(dir_path + 'penalty_inverted/contour_inverted_fit.txt')

# %%
conf_68 = contour_fit < contour_thres_68
conf_90 = contour_fit < contour_thres_90
plot_conf_contour([conf_68, conf_90], 'IH Penalty Confidence Contours', colour='red')

# %%
contour_thres_68 = load_contour_thres(dir_path + 'inverted/contour_inverse', 68)
contour_thres_90 = load_contour_thres(dir_path + 'inverted/contour_inverse', 90)
contour_fit = load_fitted_contour(dir_path + 'inverted/contour_inverse_fit.txt')

# %%
conf_68 = contour_fit < contour_thres_68
conf_90 = contour_fit < contour_thres_90
plot_conf_contour([conf_68, conf_90], 'IH Confidence Contours', colour='red')

# %%
contour_thres_68 = load_contour_thres(dir_path + 'normal/contour', 68)
contour_thres_90 = load_contour_thres(dir_path + 'normal/contour', 90)
contour_fit = load_fitted_contour(dir_path + 'normal/contour_fit.txt')

# %%
conf_68 = contour_fit < contour_thres_68
conf_90 = contour_fit < contour_thres_90
plot_conf_contour([conf_68, conf_90], 'NH Confidence Contours', colour='blue')

# %%
from helper import smooth_grid

# %%
contour_thres_68 = smooth_grid(contour_thres_68, 50)
contour_thres_90 = smooth_grid(contour_thres_90, 50)
contour_fit = smooth_grid(contour_fit, 50)

# %%
conf_68 = contour_fit < contour_thres_68
conf_90 = contour_fit < contour_thres_90
plot_conf_contour([conf_68, conf_90], 'NH Confidence Contours', colour='blue')
